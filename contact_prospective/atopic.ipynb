# %%
import sys
from pymongo import MongoClient
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
pd.set_option('display.max_rows', 500)
from scipy import stats
from scipy.stats import chi2_contingency 
import seaborn as sns
import dns

pd.set_option('display.max_columns', None)

# %%
client = MongoClient("mongodb+srv://admin-zvika:5293612aA!@cluster0.krwkt.mongodb.net/?retryWrites=true&w=majority")
db = client.test
patients=db.patients
data = pd.DataFrame(list(patients.find({})))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# C:\JupyterLab\resources\jlab_server\lib\site-packages\pymongo\pool.py in _get_socket(self, all_credentials)
#    1393                     with self.lock:
# -> 1394                         sock_info = self.sockets.popleft()
#    1395                 except IndexError:
#
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# OperationFailure                          Traceback (most recent call last)
# C:\Users\577C~1\AppData\Local\Temp/ipykernel_12836/3510143239.py in <module>
#       2 db = client.test
#       3 patients=db.patients
# ----> 4 data = pd.DataFrame(list(patients.find({})))
#
# C:\JupyterLab\resources\jlab_server\lib\site-packages\pymongo\cursor.py in next(self)
#    1236         if self.__empty:
#    1237             raise StopIteration
# ...

# %%
client = MongoClient("mongodb+srv://admin-zvika:5293612aA!@cluster0.krwkt.mongodb.net/Atopic")
db = client.get_database('Atopic')
patients=db.patients
data = pd.DataFrame(list(patients.find({})))
# data=data[:-1]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# C:\JupyterLab\resources\jlab_server\lib\site-packages\pymongo\pool.py in _get_socket(self, all_credentials)
#    1393                     with self.lock:
# -> 1394                         sock_info = self.sockets.popleft()
#    1395                 except IndexError:
#
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# OperationFailure                          Traceback (most recent call last)
# C:\Users\577C~1\AppData\Local\Temp/ipykernel_12836/1235724977.py in <module>
#       2 db = client.get_database('Atopic')
#       3 patients=db.patients
# ----> 4 data = pd.DataFrame(list(patients.find({})))
#       5 # data=data[:-1]
#
# C:\JupyterLab\resources\jlab_server\lib\site-packages\pymongo\cursor.py in next(self)
#    1236         if self.__empty:
# ...

# %%
data[30:]
# Out:
#                           _id         ID  GENDER   AGE       TIME  __v  \
# 30   625bdca641351fbe94794c8f   17673930  Female  1973  17-4-2022    0
# 31   625bdd0e41351fbe94794c91   24413148  Female  1969  17-4-2022    0
# 32   625bdd3041351fbe94794c93   31770357  Female  1974  17-4-2022    0
# 33   625bdd8241351fbe94794c95   56136013    Male  1959  17-4-2022    0
# 34   625bddbc41351fbe94794c97   25462235  Female  1973  17-4-2022    0
# 35   625bddee41351fbe94794c99   64789472  Female  1941  17-4-2022    0
# 36   625be11441351fbe94794c9b  209532720    Male  1999  17-4-2022    0
# 37   625be1b941351fbe94794c9d  318787488  Female  1997  17-4-2022    0
# 38   625be23941351fbe94794c9f   22504997  Female  1966  17-4-2022    0
# 39   625be2e041351fbe94794ca1  204291777  Female  1993  17-4-2022    0
# 40   625be33b41351fbe94794ca3  303120232    Male  1989  17-4-2022    0
# 41   625be46b41351fbe94794ca5   24066276  Female  1968  17-4-2022    0
# ...

# %%
data.columns
# Out:
# Index(['_id', 'ID', 'GENDER', 'AGE', 'TIME', '__v', 'testtype1', 'testnum1',
#        'testres1', 'testrel1', 'testtype2', 'testnum2', 'testres2', 'testrel2',
#        'testtype3', 'testnum3', 'testres3', 'testrel3', 'testtype4',
#        'testnum4', 'testres4', 'testrel4', 'testtype5', 'testnum5', 'testres5',
#        'testrel5', 'testtype6', 'testnum6', 'testrel6', 'testtype7',
#        'testnum7', 'testres7', 'testrel7', 'testtype9', 'testnum9', 'testrel9',
#        'testtype10', 'testnum10', 'testres10', 'testrel10', 'testtype11',
#        'testnum11', 'testres11', 'testrel11', 'testtype12', 'testnum12',
#        'testres12', 'testrel12', 'testres6', 'testtype8', 'testnum8',
#        'testres8', 'testrel8', 'DURATIONYEARS', 'DURATIONMONTHS', 'PROSTHESIS',
#        'OCUPATION', 'PART', 'ATOPIC', 'LACGEL', 'IMMUNESUPRESSION', 'TESTS',
#        'FAMILYATOPIC', 'OCUPATIONREL', 'NOTES', 'RESEARCHTYPE'],
#       dtype='object')
