# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy

# %%
data=pd.read_excel('Desktop/notebooks/seminar/Ground data.xlsx')

# %%
data.head()
a=data.loc[data.ID_Block=='A']
b=data.loc[data.ID_Block=='B']

plant_vars=[col for col in a.columns if col.startswith('Plant')]
soil_vars=[col for col in a.columns if col.startswith('Soil')]

# %%
plt.figure(figsize=(15,8))
a_melted=pd.melt(a,id_vars='ID_Type',value_vars=plant_vars)
sns.boxenplot(x="ID_Type",y='value',hue='variable',data=a_melted,order=['control','short','long'])
plt.title('A block plant variables by plot type')
plt.show()

# %%
plt.figure(figsize=(15,8))
b_melted=pd.melt(b,id_vars='ID_Type',value_vars=plant_vars)
sns.boxenplot(x="ID_Type",y='value',hue='variable',data=b_melted,order=['control','short','long'])
plt.title('B block plant variables by plot type')
plt.show()

# %%
a
# Out:
#   ID_Block  ID-Tretment  ID_Type  Soil_Organic matter  Soil_infiltration  \
# 0        A            1     long             1.316667                NaN
# 1        A            2    short             1.240000                NaN
# 2        A            3  control             1.240000                NaN
# 3        A            4    short             1.093333                NaN
# 4        A            5  control             1.140000                NaN
# 5        A            6     long             1.156667                NaN
# 6        A            7    short             1.270000                NaN
# 7        A            8     long             1.110000                NaN
# 8        A            9  control             1.830000                NaN
#
#    Soil_moisture upto 15  Soil_moisture upto 30  Runoff_TSS Sum  \
# 0                  42.55                  32.55             NaN
# 1                  34.00                  28.70             NaN
# 2                  50.55                  29.25             NaN
# 3                  39.00                  21.95             NaN
# 4                  52.10                  27.15             NaN
# 5                  37.40                  23.20             NaN
# 6                  26.80                  22.30             NaN
# 7                  38.00                  26.60             NaN
# 8                  49.25                  24.95             NaN
#
#    Runoff_P Total sum  Runoff_N Ammonia sum  Plant_cover  Plant_height  \
# 0                 NaN                   NaN    98.000000    107.000000
# 1                 NaN                   NaN    90.833333     57.336667
# 2                 NaN                   NaN     0.000000      0.000000
# 3                 NaN                   NaN   100.000000     62.985000
# 4                 NaN                   NaN     0.000000      0.000000
# 5                 NaN                   NaN    89.166667     11.158333
# 6                 NaN                   NaN    87.500000      0.915000
# 7                 NaN                   NaN    66.666667      0.663333
# 8                 NaN                   NaN     0.000000      0.000000
#
#    Plant_diversity  Plant_ richness  Insect_Pest richness  \
# 0         9.600000        23.000000                   NaN
# 1         8.000000        19.833333                   NaN
# 2         0.000000         0.000000                   NaN
# 3         7.666667        20.333333                   NaN
# 4         0.000000         0.000000                   NaN
# 5         6.833333        15.166667                   NaN
# 6         6.500000        13.666667                   NaN
# 7         5.833333         9.666667                   NaN
# 8         0.000000         0.000000                   NaN
#
#    Insect_Benificial richness  Insect_Total insect richness
# 0                         NaN                           NaN
# 1                         NaN                           NaN
# 2                         NaN                           NaN
# 3                         NaN                           NaN
# 4                         NaN                           NaN
# 5                         NaN                           NaN
# 6                         NaN                           NaN
# 7                         NaN                           NaN
# 8                         NaN                           NaN

# %%
pearson_r = scipy.stats.pearsonr(a['Soil_moisture upto 30'], a.Plant_height)

plt.figure(figsize=(15,8))

sns.regplot(x='Soil_moisture upto 30', y='Plant_height', data=a)
plt.annotate(f'R^2:{pearson_r[0].round(3)}',(22,100))
plt.title('Plant height by soil moisture in Plot A')
plt.show()

# %%
pearson_r
# Out:
# (0.4431095048164404, 0.2322662399426736)
